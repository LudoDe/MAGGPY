# %%
# %load_ext autoreload
# %autoreload 2

import  numpy               as np
import  matplotlib.pyplot   as plt
import  astropy.units       as u
from    pathlib             import Path
from    astropy.cosmology   import Planck18 as Planck
from itertools import product
plt.style.use('./configurations/style.mplstyle')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#pop to study 
pop         = "MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat"

alpha_vals = [
    "A0.5", "A1.0", "A3.0", "A5.0"
]

base_path = Path("datafiles/populations/MRD/output_sigma0.1")
all_folders = list(base_path.glob("*"))

for alpha, folder in product(alpha_vals, all_folders):
    MRD_file = folder / alpha / "BNSs" / pop
    z_c, MRD_c = np.loadtxt(MRD_file, unpack=True)
    mrd_detector_frame = MRD_c * (1 / (1 + z_c))
    mrd_vol = 4 * np.pi * Planck.differential_comoving_volume(z_c).to(u.Gpc ** 3 / u.sr).value
    mr_df_def = mrd_detector_frame * mrd_vol
    
    # take the 2 smallest redshifts, draw a line between them, the point at z = 0 is the local rate
    sorted_indices = np.argsort(z_c)
    z_c = z_c[sorted_indices]
    mr_df_def = mr_df_def[sorted_indices]
    
    # Get the local rate (z = 0)
    r_0 = mr_df_def[0]
    
    # Plot the merger rate density
    plt.plot(z_c, mr_df_def)
    plt.scatter([0], [r_0], color='red', zorder=5)
    
plt.xlabel("Redshift (z)")
plt.ylabel("Merger Rate Density (Gpc$^{-3}$ yr$^{-1}$ sr$^{-1}$)")
plt.title("Merger Rate Density vs Redshift")
plt.legend()
plt.grid()
plt.yscale('log')
plt.ylim(1e-3, None)
plt.xlim(0, 2)
plt.show()
# Out:
# /tmp/ipykernel_17828/3665382763.py:33: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import json

#pop to study 
pop = "MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat"

alpha_vals = [
    "A0.5", "A1.0", "A3.0", "A5.0"
]

base_path = Path("datafiles/populations/MRD/output_sigma0.1")
all_folders = list(base_path.glob("*"))

# Initialize the calculated local rates dictionary
calculated_local_rates = {}

print("Calculated Local Rates (Gpc^-3 yr^-1):")
print("=" * 60)

for alpha in alpha_vals:
    calculated_local_rates[alpha] = {}
    
    for folder in all_folders:
        MRD_file = folder / alpha / "BNSs" / pop
        if MRD_file.exists():
            z_c, MRD_c = np.loadtxt(MRD_file, unpack=True)
            mrd_detector_frame = MRD_c * (1 / (1 + z_c))
            mrd_vol = 4 * np.pi * Planck.differential_comoving_volume(z_c).to(u.Gpc ** 3 / u.sr).value
            mr_df_def = mrd_detector_frame #* mrd_vol
            
            # take the 2 smallest redshifts, draw a line between them, the point at z = 0 is the local rate
            sorted_indices  = np.argsort(z_c)
            z_c             = z_c[sorted_indices]
            mr_df_def       = mr_df_def[sorted_indices]
            
            # Get the local rate (z = 0)
            r_0 = mr_df_def[0]
            
            # Extract model name from folder
            model_name = folder.name
            
            # Store in dictionary
            calculated_local_rates[alpha][model_name] = r_0

# Print the JSON structure
print("\n" + "=" * 60)
print("Calculated Local Rates Dictionary:")
print("=" * 60)
print(json.dumps(calculated_local_rates, indent=4))

# Save to file
with open('calculated_local_rates.json', 'w') as f:
#         "fiducial_l01": 163.43434049732411,
#         "fiducial_notides": 103.95067327365479,
#         "fiducial_notides_pericirc": 212.16134409217142,
#         "fiducial_pisnfarmer19": 129.92170198121715,
#         "fiducial_qcbse": 9.498389181962128,
#         "fiducial_qhe": 129.75731183698394,
#         "fiducial_rad": 32.9841673848954,
#         "fiducial_xuli": 113.69276600414231
#     }
# }

# %%
#Save the samples to the data folder keeping the same format as the other populations
np.savetxt(datafolder/f"samples_{pop}", samples)

# %% [markdown]
# # Download and produce populations for All

# %%
import requests
import urllib.parse
from pathlib import Path

# Parameters
project     = "iogiul/iorio22_plot"  # Correct project identifier
branch      = "v3"
base_path   = "Merger_rate/cosmo_rate_bavera"  # Corrected case to 'Merger_rate'

# Encode project id for the API call
project_id = urllib.parse.quote(project, safe='')

# GitLab API endpoint for repository tree
api_url = f"https://gitlab.com/api/v4/projects/{project_id}/repository/tree"

# Get contents of the base directory
params = {'ref': branch, 'path': base_path, 'per_page': 2000, 'recursive': True}  # Added per_page to handle more entries
response = requests.get(api_url, params=params)
if response.status_code != 200:
    raise Exception(f"Error fetching repository tree: {response.status_code} - {response.text}")
entries = response.json()

mrd_files = []
for entry in entries:
    if entry["type"] == "tree":
        subdir = entry["path"]
        # Retrieve all pages for subdirectories with many entries
        page = 1
        while True:
            params_sub = {'ref': branch, 'path': subdir, 'per_page': 2000, 'page': page}
            sub_response = requests.get(api_url, params=params_sub)
            if sub_response.status_code != 200:
                break
            sub_entries = sub_response.json()
            if not sub_entries:
                break
            for item in sub_entries:
                if item["type"] == "blob" and item["name"].startswith("MRD"):
                    mrd_files.append(item["path"])
            page += 1
    elif entry["type"] == "blob" and entry["name"].startswith("MRD"):
        mrd_files.append(entry["path"])

print("Found MRD files:")
for f in mrd_files:
    print(f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 31
#      29 while True:
#      30     params_sub = {'ref': branch, 'path': subdir, 'per_page': 2000, 'page': page}
# ---> 31     sub_response = requests.get(api_url, params=params_sub)
#      32     if sub_response.status_code != 200:
#      33         break
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/numba_env/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
from pathlib import Path

# Define parameters used previously
project = "iogiul/iorio22_plot"
branch = "v3"
base_path = "Merger_rate/cosmo_rate_bavera"  # Base path used when listing files

# Folder where files will be saved:
save_dir = Path("datafiles/populations/MRD")
save_dir.mkdir(parents=True, exist_ok=True)

# Base URL for raw file download (GitLab uses the "-/raw" notation)
base_raw_url = f"https://gitlab.com/{project}/-/raw/{branch}/"

# Download and save each file from mrd_files that contains '/BNSs/' in its path.
for repo_file in mrd_files:
    if "/BNSs/" in repo_file:
        # Build the raw URL for the file
        raw_url = f"{base_raw_url}{repo_file}"
        
        response = requests.get(raw_url)
        if response.status_code == 200:
            # Optional: remove base_path from repo_file to preserve only the subfolder structure.
            try:
                relative_path = Path(repo_file).relative_to(base_path)
            except ValueError:
                relative_path = Path(repo_file)
            # Build full local file path under save_dir
            local_file = save_dir / relative_path
            local_file.parent.mkdir(parents=True, exist_ok=True)
            with open(local_file, 'wb') as f:
                f.write(response.content)
            print(f"Saved {local_file}")
        else:
            print(f"Failed to download {raw_url}: {response.status_code}")
# Out:
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Saved datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat

# %%
import shutil
from pathlib import Path

# Define the source directory containing the .dat files
source_dir = Path("datafiles/populations/MRD/output_sigma0.1")
# Define the destination directory for the extracted/renamed files
dest_dir = Path("datafiles/populations/MRD/extracted")
dest_dir.mkdir(parents=True, exist_ok=True)

# Walk recursively through the source directory and process .dat files that are within a '/BNSs/' folder.
for dat_file in source_dir.rglob("*.dat"):
    if "/BNSs/" in dat_file.as_posix():
        try:
            # Assuming the file structure is:
            # .../output_sigma0.1/{model_folder}/{A_folder}/BNSs/<filename>.dat
            bnss_dir = dat_file.parent         # This should be "BNSs"
            A_folder = bnss_dir.parent          # For example, "A0.5"
            model_folder = A_folder.parent      # For example, "fiducial_delayed"
        except Exception as e:
            print("Error extracting folder names for", dat_file, ":", e)
            continue
        
        # Construct the new filename preserving the model folder and A folder information.
        new_name = f"{model_folder.name}_{A_folder.name}_BNSs_{dat_file.name}"
        new_file = dest_dir / new_name
        
        # Ensure the destination directory exists (if you want flat structure, no nested dirs)
        new_file.parent.mkdir(parents=True, exist_ok=True)
        shutil.copy2(dat_file, new_file)
        print(f"Copied:\n  {dat_file}\n-> {new_file}")
# Out:
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_xuli_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_xuli_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_xuli_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_xuli/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_xuli_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_rad_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_rad_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_rad_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_rad/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_rad_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_qhe_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_qhe_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_qhe_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_qhe/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_qhe_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_qcbse_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_qcbse_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_qcbse_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_qcbse/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_qcbse_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_pisnfarmer19_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_pisnfarmer19_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_pisnfarmer19_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_pisnfarmer19/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_pisnfarmer19_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_notides_pericirc_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_notides_pericirc_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_notides_pericirc_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_notides_pericirc/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_notides_pericirc_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_notides_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_notides_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_notides_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_notides/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_notides_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_l01_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_l01_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_l01_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_l01/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_l01_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_klencki_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_klencki_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_klencki_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_klencki/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_klencki_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_kick265_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_kick265_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_kick265_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_kick265/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_kick265_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_kick150_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_kick150_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_kick150_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_kick150/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_kick150_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_Hrad_5M_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_Hrad_5M_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_Hrad_5M_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad_5M/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_Hrad_5M_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_Hrad_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_Hrad_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_Hrad_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_Hrad/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_Hrad_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_HGoptimistic_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_HGoptimistic_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_HGoptimistic_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_HGoptimistic/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_HGoptimistic_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_fmtbse_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_fmtbse_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_fmtbse_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_fmtbse/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_fmtbse_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A5.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_delayed_A5.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A3.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_delayed_A3.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A1.0/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_delayed_A1.0_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# Copied:
#   datafiles/populations/MRD/output_sigma0.1/fiducial_delayed/A0.5/BNSs/MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
# -> datafiles/populations/MRD/extracted/fiducial_delayed_A0.5_BNSs_MRD_spread_15Z_40_No_MandF2017_0.1_No_No_0.dat
